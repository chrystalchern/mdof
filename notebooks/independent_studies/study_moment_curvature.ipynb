# %% [markdown]
# # Plotting Exercise with a Moment-Curvature Graph

# %% [markdown]
# ## Plot existing data

# %% [markdown]
# We want to recreate the plot shown below by eyeballing the datapoints. Start with the red line, the idealized moment-curvature curve.
#
# <img src="../uploads/moment_curvature/mom_curv.png" width="500" alt="moment curvature" />

# %% [markdown]
# ## Plot the idealized moment-curvature relationship.

# %%
import matplotlib.pyplot as plt

# %%
x = [0, 0.0014, 0.007]
y = [0, 11000, 11000]

plt.plot(x, y)

# %% [markdown]
# ## Can you try making the true moment curvature plot? Fill in the below!

# %%
x = [..., ..., ..., ..., ..., ..., ...]
y = [..., ..., ..., ..., ..., ..., ...]

# what command do we use to plot a line plot of x and y? it starts with plt.
