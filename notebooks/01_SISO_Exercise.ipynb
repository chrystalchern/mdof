# %% [markdown]
# # SISO Exercise

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Consider the following single-degree-of-freedom "damped oscillator".
#
# parameter | value
# ----------|-------
# m  | mass
# k  | stiffness
# c  | damping coefficient

# %% [markdown]
# ![sdof](./figures/sdof.png)

# %% [markdown]
# The oscillator is subject to the following forcing function:
#
# $f(t) = e^{-at}\sin{bt}$

# %%
a = 1
b = np.pi
nt = 100
dt = 0.1
time = np.arange(0,nt*dt,dt)
force = np.exp(-a*time)*np.sin(b*time)
plt.plot(time, force)
plt.title(f"Forcing over time ({a=:.2f}, {b=:.2f})")
# Out:
# Text(0.5, 1.0, 'Forcing over time (a=1.00, b=3.14)')

# %% [markdown]
# ## 1. Determine the response of the oscillator.

# %% [markdown]
# The differential equation governing the motion of the oscillator is given below.
#
# $m\ddot{u} + c\dot{u} + ku = f(t), \quad{} u(0)=u_{0}, \quad{} \dot{u}(0)=\dot{u}_{0}$.
#
# Solve the differential equation with the given forcing function, $f(t) = e^{-at}\sin{bt}$, to determine the displacement response of the oscillator, $u(t)$, over time.
#
# Assume $c^{2}-4mk < 0$.  That is, there are two complex roots to the characteristic polynomial $m\lambda^{2}+c\lambda+k$, and there are two independent homogeneous solutions of the form $e^{\alpha\pm\beta i}$.
#
# Also assume $b \neq \frac{\sqrt{4mk-c^{2}}}{2m}$.  That is, the solutions $e^{-at}\cos{bt}$ and $e^{-at}\sin{bt}$ are independent of the homogeneous solutions.
#
# Keep your answer symbolic in terms of $m$, $c$, $k$, $a$, $b$, $u_{0}$, and $\dot{u}_{0}$.  Feel free to use [Sympy](https://certik.github.io/scipy-2013-tutorial/html/tutorial/basic_operations.html), [Matlab symbolic](https://www.mathworks.com/help/symbolic/physics-damped-harmonic-oscillator.html), [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/algebra/equation-solving/), or other symbolic math equation solvers for assistance.
#
# Enter your answer in the [latex math language](https://www.fabriziomusacchio.com/blog/2021-08-10-How_to_use_LaTeX_in_Markdown/) in the Markdown cell below.

# %% [markdown]
# $$u(t) = ...$$

# %% [markdown]
# ## 2. Plot the response of the oscillator.

# %% [markdown]
# For given parameter values $m$, $c$, $k$, $a$, $b$, $u_{0}$, and $\dot{u}_{0}$, plot the displacement response of the oscillator.  Play around with different parameter values to observe how the response changes.

# %%
m = 1
c = 0.1
k = 3
a = 1
b = np.pi
u0 = 0
udot0 = 0

response = ...
# plt.plot(...)
plt.title("Displacement over time\n"
          rf"({a=:.2f}, {b=:.2f}, {m=:.2f}, {c=:.2f}, {k=:.2f}, $u_{0}$={u0}, $\dot u_{0}$={udot0})")
# Out:
# Text(0.5, 1.0, 'Displacement over time\n(a=1.00, b=3.14, m=1.00, c=0.10, k=3.00, $u_0$=0, $\\dot u_0$=0)')
