# %% [markdown]
# # San Bernardino

# %% [markdown]
# ![](ll23631_1.svg)

# %%
import quakeio
import quakeio.processing as proc

# %%
c = quakeio.read("../dat/BigBear92_ce23631p.zip", exclusions=["filter*"])

# %%
proc.Spectrum(c.motions["north_abutment"].long, damping=[0.001, 0.01]).plot();
