# %%
import quakeio
import ssid
from pathlib import Path
import numpy as np

# %%
# config = dict(# Case 2
#     bridge  = "hayward",
#     inputs  = [3,6,17],
#     outputs = [12, 14, 19]
# )
config = dict( # Case 5
    bridge  = "hayward",
    inputs  = [1],
    outputs = [16]
)
# config = dict(
#     inputs  = "2 7 25".split(),
#     outputs = "18 13 15 23 20".split()
# )

# %%
for file in Path(config["bridge"]).glob("*.P.zip"):
    event = quakeio.read(file)
    try:
        inputs = [
            event.match("r", file_name=f".*{chan}.*").accel
            for chan in config["inputs"]
        ]
        outpts = [
            event.match("r", file_name=f".*{chan}.*").accel
            for chan in config["outputs"]
        ]
    except:
        print(f"failed {file.name}")
        
    else:
        dt = inputs[0]["time_step"]
        A,B,C,D = ssid.srim(inputs, outpts, dt=dt, mro=25,orm=10,verbose=True)
        
        freqdmpSRIM, modeshapeSRIM, *_ = si.ComposeModes(dt, A, B, C, D)
        # Add validation
        print(si.IdentifiedSystem(dt, A, B, C, D))
        # print(file, np.real(1/freqdmpSRIM[:,0]))
# Out:
# 100%|██████████████████████████████████████████████████████▉| 14975/14976 [01:15<00:00, 198.35it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.08626  11.59   0.0009889
#     0.03206  31.19   0.04058
#     0.07785  12.84   0.02907
#     0.07785  12.84   0.02907
#     0.04417  22.64   0.006707
#     0.04417  22.64   0.006707
#     0.02721  36.75   0.002446
#     0.02721  36.75   0.002446
# 100%|████████████████████████████████████████████████████████▉| 8575/8576 [00:25<00:00, 333.64it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02739  36.51   0.004398
#     0.0877  11.4    0.1646
#     0.03605  27.74   0.01227
#     0.03605  27.74   0.01227
#     0.2902  3.446   0.02053
#     0.2902  3.446   0.02053
#     0.5881  1.7     0.1093
#     0.5881  1.7     0.1093
#
# failed 58486_007_20211117_11.43.20.P.zip
# 100%|██████████████████████████████████████████████████████▉| 14975/14976 [01:16<00:00, 195.12it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.105   9.524   0.00707
#     0.02824  35.41   0.08016
#     0.04271  23.41   0.0351
#     0.04271  23.41   0.0351
#     0.03121  32.04   0.02893
#     0.03121  32.04   0.02893
#     0.02788  35.87   0.009725
#     0.02788  35.87   0.009725
# 100%|████████████████████████████████████████████████████████▉| 7775/7776 [00:22<00:00, 348.03it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.07026  14.23   -0.001869
#     0.03191  31.34   0.09532
#     0.1023  9.772   0.01582
#     0.1023  9.772   0.01582
#     0.02724  36.71   0.002466
#     0.02724  36.71   0.002466
#     0.03725  26.85   0.01638
#     0.03725  26.85   0.01638
# 100%|██████████████████████████████████████████████████████▉| 14975/14976 [01:15<00:00, 197.05it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.0276  36.23   0.01298
#     0.09403  10.64   0.4704
#     0.0785  12.74   0.04888
#     0.0785  12.74   0.04888
#     0.1168  8.56    0.03431
#     0.1168  8.56    0.03431
#     0.2151  4.648   0.08443
#     0.2151  4.648   0.08443
#
# failed 58486_006_20210628_18.29.21.P.zip
# 100%|████████████████████████████████████████████████████████▉| 7875/7876 [00:22<00:00, 352.80it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.06346  15.76   0.03892
#     0.03251  30.76   0.01408
#     0.02688  37.2    0.003813
#     0.02688  37.2    0.003813
#     0.03692  27.08   0.008739
#     0.03692  27.08   0.008739
#     0.03018  33.14   0.0118
#     0.03018  33.14   0.0118
# 100%|██████████████████████████████████████████████████████▉| 13275/13276 [01:03<00:00, 209.48it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0
/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.08945  11.18   0.002884
#     0.03021  33.1    0.01254
#     0.06881  14.53   0.1229
#     0.06881  14.53   0.1229
#     0.0278  35.97   0.001908
#     0.0278  35.97   0.001908
#     0.03334  30.0    0.002799
#     0.03334  30.0    0.002799
#
# failed 58486_003_20210322_12.43.52.P.zip
# 100%|████████████████████████████████████████████████████████▉| 6575/6576 [00:15<00:00, 419.19it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02577  38.81   -0.0003834
#     0.05053  19.79   0.2218
#     0.1054  9.485   0.01537
#     0.1054  9.485   0.01537
#     0.07477  13.38   0.09955
#     0.07477  13.38   0.09955
#     0.06749  14.82   0.06393
#     0.06749  14.82   0.06393
# 100%|██████████████████████████████████████████████████████▉| 12775/12776 [00:55<00:00, 231.93it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02853  35.05   0.005746
#     0.03692  27.08   0.007162
#     0.03692  27.08   0.007162
#     0.08551  11.69   0.02357
#     0.08551  11.69   0.02357
#     0.08009  12.49   0.03565
#     0.08009  12.49   0.03565
# 100%|████████████████████████████████████████████████████████▉| 6775/6776 [00:15<00:00, 431.63it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.06854  14.59   0.01657
#     0.3264  3.064   0.02883
#     0.09051  11.05   -0.01794
#     0.09051  11.05   -0.01794
#     0.1343  7.444   0.01708
#     0.1343  7.444   0.01708
#     0.2344  4.266   0.04503
#     0.2344  4.266   0.04503
# 100%|██████████████████████████████████████████████████████▉| 12175/12176 [00:49<00:00, 246.33it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02649  37.75   0.005075
#     0.07299  13.7    0.01911
#     0.03427  29.18   0.01171
#     0.03427  29.18   0.01171
#     0.04088  24.46   0.0158
#     0.04088  24.46   0.0158
#     0.1091  9.165   0.003676
#     0.1091  9.165   0.003676
# 100%|██████████████████████████████████████████████████████▉| 12975/12976 [00:56<00:00, 228.65it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02809  35.6    0.002036
#     0.03812  26.24   0.00972
#     0.03812  26.24   0.00972
#     0.08967  11.15   0.01061
#     0.08967  11.15   0.01061
#     0.0637  15.7    0.07089
#     0.0637  15.7    0.07089
# 100%|██████████████████████████████████████████████████████▉| 12175/12176 [00:49<00:00, 247.89it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.0277  36.1    0.004922
#     0.03664  27.29   0.004988
#     0.03664  27.29   0.004988
#     0.05924  16.88   0.04839
#     0.05924  16.88   0.04839
#     0.09519  10.5    0.01611
#     0.09519  10.5    0.01611
# 100%|██████████████████████████████████████████████████████▉| 12175/12176 [00:49<00:00, 244.87it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02589  38.63   0.002516
#     0.07427  13.46   0.116
#     0.03544  28.22   -0.001675
#     0.03544  28.22   -0.001675
#     0.09989  10.01   0.1364
#     0.09989  10.01   0.1364
#     0.06797  14.71   0.01165
#     0.06797  14.71   0.01165
# 100%|██████████████████████████████████████████████████████▉| 12975/12976 [00:55<00:00, 233.34it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.02902  34.46   0.007234
#     0.1282  7.801   0.5676
#     0.03654  27.37   0.008023
#     0.03654  27.37   0.008023
#     0.09415  10.62   0.0145
#     0.09415  10.62   0.0145
#     0.07977  12.54   0.005951
#     0.07977  12.54   0.005951
# 100%|██████████████████████████████████████████████████████▉| 11075/11076 [00:46<00:00, 240.12it/s]
# Spectral quantities:
#        T      𝑓       ζ
#     0.04583  21.82   0.04134
#     0.06583  15.19   0.01537
#     0.3375  2.963   0.7176
#     0.3375  2.963   0.7176
#     0.08965  11.15   0.008116
#     0.08965  11.15   0.008116
#     0.06878  14.54   0.004907
#     0.06878  14.54   0.004907
