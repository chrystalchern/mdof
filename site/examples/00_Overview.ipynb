# %% [markdown]
# # Overview of the ``mdof`` package

# %% [markdown]
# <div>
# <img src="./figures/mdof_overview.png" width="200"/>
# </div>

# %% [markdown]
# The `mdof` package is designed to provide a convenient interface for computing dynamic analyses of structural vibrations.

# %% [markdown]
# ## Installation

# %% [markdown]
# If you'd like to install `mdof` in your own environment to work with it locally, install mdof from [pypi](https://pypi.org/project/mdof/).  In your environment manager (e.g., Anaconda),
#
# ```bash
#     pip install mdof
# ```

# %% [markdown]
# ## Import

# %% [markdown]
# In Python, import the package.

# %%
import mdof

# %% [markdown]
# ## Investigate Structural Vibrations

# %% [markdown]
# Load an the input motion, output motion, and time vector for a mystery structural system.

# %% [markdown]
# <div><center>
# <img src="./figures/mystery_system.png" width="550"/>
# </center></div>

# %%
import numpy as np
input_motion = np.loadtxt("uploads/input_motion.txt")
output_motion = np.loadtxt("uploads/output_motion.txt")
times = np.loadtxt("uploads/times.txt")

# %%
from mdof.utilities.printing import plot_io
plot_io(input_motion, output_motion, times)

# %% [markdown]
# ### Inverse Eigenanalysis with `mdof.eigid()`

# %% [markdown]
# <div><center>
# <img src="./figures/eigid.png" width="550"/>
# </center></div>

# %%
eigvals, eigvecs = mdof.eigid(input_motion, output_motion, order=2)
# Out:
# 100%|█████████▉| 4700/4701 [00:00<00:00, 77332.86it/s]

# %%
print(f"{eigvals=}\n {eigvecs=}")
# Out:
# eigvals=array([0.98491199+0.16330168j, 0.98491199-0.16330168j])
#  eigvecs=array([[ 0.71332805+0.j        ,  0.71332805-0.j        ],
#        [-0.00497201+0.70081265j, -0.00497201-0.70081265j]])

# %% [markdown]
# ### State Space Realization with `mdof.sysid()`

# %% [markdown]
# <div><center>
# <img src="./figures/sysid.png" width="550"/>
# </center></div>

# %%
A,B,C,D = mdof.sysid(input_motion, output_motion, order=2)
# Out:
# 100%|█████████▉| 4700/4701 [00:00<00:00, 87358.87it/s]

# %%
print(f"{A=} \n{B=} \n{C=} \n{D=}")
# Out:
# A=array([[ 0.98607055,  0.16621799],
#        [-0.16044462,  0.98375342]])
# B=array([[-0.1743355 ],
#        [-0.10978558]])
# C=array([[-0.05126065,  0.08870003]])
# D=array([[-0.09489982]])

# %% [markdown]
# ### Modal Estimation with `mdof.modes()`

# %% [markdown]
# <div><center>
# <img src="./figures/modal.png" width="550"/>
# </center></div>

# %%
modes = mdof.modes(input_motion, output_motion, dt=times[1]-times[0], order=2)
# Out:
# 100%|█████████▉| 4700/4701 [00:00<00:00, 89928.92it/s]

# %%
from mdof.utilities.printing import print_modes
print_modes(modes)
# Out:
# Spectral quantities:
#        T(s)        ζ        EMACO      MPC       EMACO*MPC
#       1.147      0.01       1.0        1.0        1.0
# Mean Period(s): 1.1471474419090963
# Standard Dev(s): 0.0

# %% [markdown]
# ### Spectra with `power_transfer()` and `spectrum_modes()`

# %%
from mdof.transform import power_transfer
periods, amplitudes = power_transfer(input_motion, output_motion, step=times[1]-times[0], period_band=(0,5))

# %%
from mdof.modal import spectrum_modes
peak_period, peak_amplitude = spectrum_modes(periods, amplitudes)
print(f"{peak_period=}")
# Out:
# peak_period=array([1.14503817])

# %%
from mdof.utilities.printing import plot_transfer
plot_transfer(np.array([periods,amplitudes]), plotly=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id
958762886597,0.7692307692307692,0.7653061224489796,0.7614213197969543,0.7575757575757576,0.7537688442211056,0.7499999999999999,0.7462686567164178,0.7425742574257426,0.7389162561576353,0.7352941176470588,0.7317073170731707,0.7281553398058251,0.7246376811594202,0.7211538461538461,0.7177033492822966,0.7142857142857142,0.7109004739336493,0.7075471698113207,0.704225352112676,0.7009345794392523,0.6976744186046512,0.6944444444444443,0.6912442396313364,0.6880733944954128,0.684931506849315,0.6818181818181818,0.6787330316742082,0.6756756756756755,0.6726457399103138,0.6696428571428571,0.666 ...

# %% [markdown]
# ### Stablization Diagram with `stabilization()`

# %%
from mdof.macro import stabilization
stabilization(input_motion, output_motion, dt=times[1]-times[0], orders=(2,20,2), plotly=True)
# Out:
# 100%|█████████▉| 4700/4701 [00:00<00:00, 75231.28it/s]
# 100%|█████████▉| 4700/4701 [00:00<00:00, 44698.87it/s]
# 100%|█████████▉| 4700/4701 [00:00<00:00, 23447.11it/s]
# 100%|█████████▉| 4700/4701 [00:00<00:00, 16371.82it/s]
# 100%|█████████▉| 4700/4701 [00:00<00:00, 9064.47it/s]
# 100%|█████████▉| 4700/4701 [00:00<00:00, 8680.56it/s]
# 100%|█████████▉| 4700/4701 [00:00<00:00, 4853.57it/s]
# 100%|█████████▉| 4700/4701 [00:01<00:00, 3895.88it/s]
# 100%|█████████▉| 4700/4701 [00:01<00:00, 3513.59it/s]
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="be9d1f21-4937-4916-9665-39d978adef51" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be9d1f21-4937-4916-9665-39d978adef51")) {                    Plotly.newPlot(                        "be9d1f21-4937-4916-9665-39d978adef51",                        [{"marker":{"size":8},"mode":"markers","x":[1.1471474419090963,1.147147441909096,1.1471474419090966,1.1471474419090972,0.09497233776910163,2.7298724394455554,1.147147441909096,0.08726717815476155,2.7324652528893507,1.1471474419090966,0.05164686555901158,2.586838368023516,1.1471474419090977,0.0608463580822854,2.510247005359914,2.850181389516638,1.1471474419091012,0.07796743784622158,0.05135052407638435,2.47786837810638,3.0564822225511503,1.1471474419090961,0.07939701482704177,0.058066669981805465,2.474883755469805,3.2938054992992916],"y":[2.0,4.0,6.0,8.0,8.0,8.0,10.0,10.0,10.0,12.0,12.0,12.0,14.0,14.0,14.0,14.0,16.0,16.0,16.0,16.0,16.0,18.0,18.0,18.0,18.0,18.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"size":8},"mode":"markers","x":[0.010000000000001622,0.009999999999996055,0.009999999999997561,0.009999999999996232,0.9925374323531053,0.36118355012859027,0.009999999999996055,0.9713938612248025,0.3369613459869647,0.009999999999992723,0.9483788266104248,0.22321366861572997,0.009999999999992232,0.7694128680147424,0.19949339585665224,0.9143540807763053,0.009999999999995486,0.6061889209167992,0.7080619426803255,0.186596249318412,0.9002826645924448,0.009999999999989243,0.6214226243978875,0.6858141581762562,0.18620470158550656,0.8338621977904697],"y":[2.0,4.0,6.0,8.0,8.0,8.0,10.0,10.0,10.0,12.0,12.0,12.0,14.0,14.0,14.0,14.0,16.0,16.0,16.0,16.0,16.0,18.0,18.0,18.0,18.0,18.0],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"] ...
